# %%
from laser_tools import mirrors
from laser_tools import goggles
from laser_tools import materials
from laser_tools import polarizers
from laser_tools import waveplates
# Out:
# Layertec114572RS
# Dby C1033 C1023 T5h03 T5h05
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       2 from laser_tools import goggles
#       3 from laser_tools import materials
# ----> 4 from laser_tools import polarizers
#       5 from laser_tools import waveplates
#
# File ~/code/laser_tools/laser_tools/polarizers/__init__.py:48
#      44         created[class_name] = Child
#      46     return created
# ---> 48 _created = _register_children()
#      50 print(*_created.keys())
#      52 __all__ = ["Polarizer", *_created.keys()]
#
# File ~/code/laser_tools/laser_tools/polarizers/__init__.py:32, in _register_children()
#      29 created: Dict[str, Type[Polarizer]] = {}
#      31 if not os.path.isdir(data_dir):
# ---> 32     raise FileNotFoundError("Directory not found.")
#      34 class_names, filepaths = get_files(data_dir)
# ...

# %%
print(mirrors.available())
print(goggles.available())
print(materials.available())
print(polarizers.available())
print(waveplates.available())
# Out:
# ['Dby', 'C1033', 'C1023', 'T5h03', 'T5h05']

# %%
from laser_tools import materials
from laser_tools import polarizers
from laser_tools import waveplates

# %%
MR1K1 = mirrors.Layertec_114572_r_s()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 MR1K1 = mirrors.Layertec_114572_r_s()
#
# AttributeError: module 'laser_tools.mirrors' has no attribute 'Layertec_114572_r_s'
